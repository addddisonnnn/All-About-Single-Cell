# %%
import scanpy as sc
import anndata as ad
import matplotlib.pyplot as plt

# %% [markdown]
# # Read in samples separately (Find the appropriate function to read in 10x data from a MTX)

# %% [markdown]
# # How many cells and genes are present in each sample initially? (Use the .obs and .var of each AnnData Object)

# %% [markdown]
# # Identify which genes correspond to mitochondrial, ribosomal or hemoglobin genes (Use the beginning of the scanpy tutorial)

# %% [markdown]
# # Actually calculate QC metrics per barcode / cell (Follow the scanpy tutorial for this)

# %% [markdown]
# # Access the .obs and return a dataframe that just has cells with less than 1000 genes for each sample

# %% [markdown]
# ## This is just practice getting used to anndata / pandas style subsetting

# %% [markdown]
# # How many cells / barcodes have less than 1000 genes present?

# %% [markdown]
# You can access individual columns by anndata.obs['example_column_name']
#
# You can find which rows meet a certain condition by: anndata.obs['example_column_name'] > 500. This is a common pattern that creates a boolean mask (returns true or false for each row if it meets the condition). You can use the original dataframe to then subset to only contain the rows evaluating to True.

# %% [markdown]
# # Plot both sample's QC metrics

# %% [markdown]
# # Plot metrics jointly for each sample

# %% [markdown]
# # Actually filter your datasets based on your chosen thresholds

# %% [markdown]
# # How many genes and cells remain after filtering?

# %% [markdown]
# # Combine both samples together using concat

# %% [markdown]
# # Normalize and log + 1 transform

# %% [markdown]
# # Determine highly variable genes

# %% [markdown]
# # Inspect the highly variable genes using the .var
